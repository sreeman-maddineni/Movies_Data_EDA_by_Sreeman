# %% [markdown]
# <p align="center"><img src="https://github.com/insaid2018/Term-1/blob/master/Images/INSAID_Full%20Logo.png?raw=true" width="260" height="110" /></p>

# %% [markdown]
# ---
# # **Table of Contents**
# ---
#
# 1. [**Introduction**](#Section1)<br>
# 2. [**Problem Statement**](#Section2)<br>
# 3. [**Installing & Importing Libraries**](#Section3)<br>
#   3.1 [**Installing Libraries**](#Section31)<br>
#   3.2 [**Upgrading Libraries**](#Section32)<br>
#   3.3 [**Importing Libraries**](#Section33)<br>
# 4. [**Data Acquisition & Description**](#Section4)<br>
# 5. [**Data Pre-Profiling**](#Section5)<br>
# 6. [**Data Pre-Processing**](#Section6)<br>
# 7. [**Data Post-Profiling**](#Section7)<br>
# 8. [**Exploratory Data Analysis**](#Section8)<br>
# 9. [**Summarization**](#Section9)</br>
#   9.1 [**Conclusion**](#Section91)</br>
#   9.2 [**Actionable Insights**](#Section91)</br>
#
# ---

# %% [markdown]
# ---
# <a name = Section1></a>
# # **1. Introduction**
#
# The prediction of movie box office revenue after release has always been a challenging problem in a movie industry. Hundreds and thousands of movies are released every month and a year. The correct prediction of box office revenues is important to lessen the market risk.
#
#  - The goal of the project is to go through the dataset, analyse using numpy, pandas and matplotlib and derive meaningful insights.
#  - The data set we are going to examine contains information about 1000 movies collected from The Movie Database, including user ratings and revenue.
#
# Let's start some interesting research to take our analysis towards success of a movie before it is done.

# %% [markdown]
# ---
# <a name = Section2></a>
# # **2. Problem Statement**
# ---
#
# <b>Many movies costing over millions can still flop. The analysis plays an important role towards success of movies produced.</b></br></br>
#
#
# <img src='https://drive.google.com/uc?id=1K-dgoMuJe2O4SLhavkauO_vj2w3s1nJm' width="1080" height="380" ></img>
#
#
# </br>We will explore the director,actor, genre and more and correlation between them and check who are influencing to produce more revenue and stand as a star at box office.Also we will see the results of this analysis in an intuitive way by visualizing outcome.
#
#
# The objective of this project is to explore the Movies dataset and answers some interesting questions like popular movies, profitability analysis, kind of movies are most produced, most produced genres etc.
#
# Data points in our dataset include Rank,Title,Directors,Actors,Genre,Runtime,Revenue,Votes, Ratings etc.
#
# Imagining that based on my analysis investor going to invest in right kind of movies.
#
# Let's find out some interesting facts about dataset with some questions in mind.
#
#
#  - Year wise top movies and their Rating,Revenue,Votes etc?
#  - Highest and Lowest revenue movie exploration?
#  - Distribution analysis for runtime,votes,ratings,revenue?
#  - Which movie get the highest or lowest votes?
#  - Which Year Has The Highest revenues?
#  - Which length movies most liked by the audiences?
#  - Average Runtime Of Movies?
#  - How Does rating Depends On revenue?
#  - The Genre Has The Highest Release Of Movies?
#  - The genres are most popular?
#  - Most Frequent star cast?
#  - Top Directors with Average Rating is Higher?
#  - Top Directors Who Directs Maximum Movies?
#  - Most Filmed Genre and their revenues?
#  - What kinds of properties are associated with revenue of movies?
#
# <img src='https://drive.google.com/uc?id=1hgMHCrREZNlM-AopT3z5QBPQNITa76k4' width="580" height="320" ></img>

# %% [markdown]
# ---
# <a id = Section3></a>
# # **3. Installing & Importing Libraries**
# ---
#
# - Importing packages and libraries required

# %% [markdown]
# ### **Installing Libraries**

# %%
#Commented as it is already installed
#!pip install -q datascience                                         # Package that is required by pandas profiling
#!pip install -q pandas-profiling                                    # Library to generate basic statistics about data

# %% [markdown]
# ### **Upgrading Libraries**
#
# - **After upgrading** the libraries, you need to **restart the runtime** to make the libraries in sync.
#
# - Make sure not to execute the cell under Installing Libraries and Upgrading Libraries again after restarting the runtime.

# %%
#Commented as it is already upgraded
#!pip install -q --upgrade pandas-profiling                          # Upgrading pandas profiling to the latest version

# %% [markdown]
# ### **Importing Libraries**
#
# - Importing the libraries and packages required for the project

# %%
#-------------------------------------------------------------------------------------------------------------------------------
import pandas as pd                                                 # Importing package pandas (For Panel Data Analysis)
from pandas_profiling import ProfileReport                          # Import Pandas Profiling (To generate Univariate Analysis)
#import pandas_profiling as pp 
#-------------------------------------------------------------------------------------------------------------------------------
import numpy as np                                                  # Importing package numpys (For Numerical Python)
#-------------------------------------------------------------------------------------------------------------------------------
import matplotlib.pyplot as plt                                     # Importing pyplot interface to use matplotlib
import seaborn as sns                                               # Importing seaborn library for interactive visualization
# %matplotlib inline
#-------------------------------------------------------------------------------------------------------------------------------
import scipy as sp                                                  # Importing library for scientific calculations
#-------------------------------------------------------------------------------------------------------------------------------
import missingno as mnsg                                            # Importing for a series of visualisations
import warnings
import re                                                           # Importing to use regular expression
from pandas import Series
import plotly.express as px

# %% [markdown]
# ---
# <a name = Section4></a>
# # **4. Data Acquisition & Description**
# ---
#
# <img src='https://drive.google.com/uc?id=19dk8fmOFdVeRYdLAeUkaTFmdFEM0leQ0' width="600" ></img>
#
# The first step in visualizing data is to load it into our application.
#
# Data acquisition is the process of sampling real world physical conditions and converting the resulting samples into digital values. data aquisition can be done with different components.
#
# ---
#
# We got readily available dataset got from github with the link provided.We have only one dataset.
#
# The raw data provided in csv file, we will apply our cleaning and pre processing methods to get data, with right information.
#
# Movies dataset holds information about the directors,
# actors, year in which the movie is released and so
# on.
#
# - Before going further we will see what columns are telling us in detail:
#
# |Id|Feature|Description|
# |:--|:--|:--|
# |01|Rank|Movie Rank|
# |02| Title | Title of the movie|
# |03| Genre | The various Genre that the movie can be associated with|
# |04| Description| Short description about the movie|
# |05| Director| Director of the movie|
# |06| Actors| Main actors in the movie|
# |07| Year| Year in which the movie was released|
# |08| Runtime (minutes)| Total movie playing time|
# |09| Rating | Movie rating|
# |10| Votes| Vores for the movie|
# |11| Revenue (Millions)| Revenue by the movie (in millions)|
# |12| Metascore| Is the score of the movie on the metacritic website by critics|
#
#
# </br>We are ready with the data, Let start some interesting analysis on data

# %%
data = pd.read_csv(filepath_or_buffer = 'https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Projects/1000%20movies%20data.csv')
print('Data Shape:', data.shape)
print('\nSample Data:')
data.head(6)
# Out:
# Data Shape: (1000, 12)
#
# Sample Data:
#    Rank                    Title  ... Revenue (Millions) Metascore
# 0     1  Guardians of the Galaxy  ...             333.13      76.0
# 1     2               Prometheus  ...             126.46      65.0
# 2     3                    Split  ...             138.12      62.0
# 3     4                     Sing  ...             270.32      59.0
# 4     5            Suicide Squad  ...             325.02      40.0
# 5     6           The Great Wall  ...              45.13      42.0
#
# [6 rows x 12 columns]

# %% [markdown]
# **Observation:**
#
# Here we know that, there are 1000 rows and 12 columns.
#
# The sample data looks good and makes us more interesting to proceed.

# %% [markdown]
# ### **Data Description**
#
# - Here is the quick description of data in the form of statstics.

# %%
# Dataset Description
data.describe()
# Out:
#               Rank         Year  ...  Revenue (Millions)   Metascore
# count  1000.000000  1000.000000  ...          872.000000  936.000000
# mean    500.500000  2012.783000  ...           82.956376   58.985043
# std     288.819436     3.205962  ...          103.253540   17.194757
# min       1.000000  2006.000000  ...            0.000000   11.000000
# 25%     250.750000  2010.000000  ...           13.270000   47.000000
# 50%     500.500000  2014.000000  ...           47.985000   59.500000
# 75%     750.250000  2016.000000  ...          113.715000   72.000000
# max    1000.000000  2016.000000  ...          936.630000  100.000000
#
# [8 rows x 7 columns]

# %% [markdown]
# **Observation:**
#
# Some insights from the description table
#
#  - The min and max values in ‘Year’ depict the minimum and maximum release years.
#  - We can see that, the dataset contains movies from 2006 to 2016.
#  - Minimum values found as zero, we will check what we can do.
#  - The average rating for the movies in this dataset is about 6.7,the minimum rating is 1.9 and the maximum rating is 9.0
#  - The Votes are shown in exponential. there is no issue in data as some movies votes are there in millions. min value is 61 and max value is 791916.we will refine if required.
#  - The maximum revenue earned by a movie is 936.6 million

# %% [markdown]
# ### **Data Information**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %% [markdown]
# **Observation:**
#
#  - The data information shows us 5 categorical columns and others are numeric columns.
#  - Revenue and metascore data is missing
#  - The memory usage of data is 94 KB

# %% [markdown]
# ---
# <a name = Section5></a>
# # **5. Data Pre-Profiling**
# ---
#
# - Data pre-profiling helps us discover, understand, organize and corelations between the data.
#
# - Output file we name as Pre-Profiling_Report_MovieData.html, which will be downloaded to content of google colab.
# - Let's start downloading the pre profiling report

# %%
#Output profile report from dataframe
 
#profile=ProfileReport(data)
 
#profile.to_file("Pre-Profiling_Report_MovieData.html")

# %% [markdown]
# **Observation:**
#
# The following are the observations of Pre Profiling Report</Br>
#
# Numeric columns are 7 and categorical are 5</br>
# Total Missing cells are 1.6% </br>
# There are no duplicate rows</br>
# Total memory size of dataset is 94 kb</br></br>
#
#  - Movies data from 2006 to 2016.</br>
#  - Rank column is index column which is very clear</br>
#  - Genre is a combination of one or more,which is good to grab different audiences.</br>
#  - Votes is highly correlated with rating
#  - There are 644 different directors in our data. </br>
#  - Runtime of movie in minutes, min is 66 and max is 191.</br>
#  - Users participated well in votes. Good to see 1.7 million votes for "The dark knight" movie, which is favourite for many.</br>
#  - Here important data Revenue in millions. revenue data for 128 movies are missing which is 12.8% of total data. minimum revenue collection is 0.01 and maximum is 936 millions.. Wow!.</br>
#   - Revenue column is positively skeiwed and has outliers.
#   - Q3 (75th percentile) and 95th percentile are 113.71 and 293.88 respectively, max is 936.63
#  - Metascore, which is critics rating ranging from 11 to 100, having 64 cells with missing data which is 6.4% of total data.It is symmetrically distributed</br>
#  - Ratings are having symmetrical distribution and no outliers.
#
#  - Genre is a combination of one or more.
#
# By observing some first and last rows, Title has got some special characters.

# %% [markdown]
# ---
# <a name = Section6></a>
# # **6. Data Pre-Processing**
# ---
#
# - The data requires some preprocessing before we analyzing the model and making the predictions.
#
# - In pre processing phase, we will do the following :
#   - Handling missing data,
#
#   - Handling redundant data,
#
#   - Handling inconsistent data,
#
#   - Handling outliers,
#
#   - Handling typos

# %% [markdown]
# <img src='https://drive.google.com/uc?id=1BKpQ671W2lCuo8Y2iRsdrIF1Vw0KB1Lz' width="800"></img>

# %% [markdown]
# ###**Handling column names**
#
#  - Creating a New Dataframe from existing dataframe and working on it
#  - Rename the columns of data: Runtime and Revenue
#  - Renaming Column Names because Special Characters may Become issue Sometimes
#  - Making all columns to lowercase, for easier identification of column names
#  - Creating another dataset **"df_movie"** with these new columns and preserving original

# %%
df_Movie = data.rename(columns = {'Runtime (Minutes)': 'Runtime_Minutes', 'Revenue (Millions)': 'Revenue_Millions'}, inplace = False)
df_Movie.columns = df_Movie.columns.str.lower()

# %%
df_Movie.columns
# Out:
# Index(['rank', 'title', 'genre', 'description', 'director', 'actors', 'year',
#        'runtime_minutes', 'rating', 'votes', 'revenue_millions', 'metascore'],
#       dtype='object')

# %% [markdown]
# ### **Handling Null Values**

# %%
mnsg.bar(df_Movie,figsize=(10,2),color='CornFlowerBlue')
warnings.filterwarnings( "ignore", module = "matplotlib\..*" )

# %% [markdown]
# **Observation:**
#
# Revenue and Metascore are having missing values. 12.8 % of Revenue ad 6.4 % of Metascore values are missing.
#
# we observed the same in pre profile report. we will handle this.

# %% [markdown]
# ##### **Checking for Zeros**

# %%
# Checking for a zero values in the Revenue columns
print("Rows With Zero In The Revenue are:",df_Movie[(df_Movie['revenue_millions']==0)].shape[0])
# Checking for an zero values in the Metascore columns
print("Rows With Zero In The Metascore are:",df_Movie[(df_Movie['metascore']==0)].shape[0])
# Out:
# Rows With Zero In The Revenue are: 1
# Rows With Zero In The Metascore are: 0

# %% [markdown]
# **Observation:**
#
# Replacing one row having revenue as 0 with null, we will handle all null rows at once.

# %% [markdown]
# ##### **Checking distribution**

# %%
df_Movie.revenue_millions.replace(0,np.nan, inplace = True)

# %%
fig, ax =plt.subplots(1,2)
sns.boxplot(data=df_Movie.revenue_millions, ax=ax[0],color='CornFlowerBlue')
sns.boxplot(data=df_Movie.metascore, ax=ax[1],color='CornFlowerBlue')
sns.set_style("whitegrid")
fig.show()

warnings.filterwarnings( "ignore", module = "matplotlib\..*" )

# %% [markdown]
# **Observation:**
#
# By observing above graphs and data.
#
#  - The data is skeiwed for revenue_millions column. Outliers data points will have a significant impact on the mean and hence the revenue_millions decided to replace with median for null values.
#  - The graph of metascore shows symmetric data distribution hence the metascore decided to replace with mean for null values.

# %%
# Using median on revenue_millions
df_Movie['revenue_millions'].fillna(df_Movie['revenue_millions'].median(), inplace=True)
  
# Using mean on metascore
df_Movie['metascore'].fillna(int(df_Movie['metascore'].mean()), inplace=True)

# %%
df_Movie.shape
# Out:
# (1000, 12)

# %%
percent_missing = df_Movie.isnull().sum() * 100 / len(df_Movie)
percent_missing
# Out:
# rank                0.0
# title               0.0
# genre               0.0
# description         0.0
# director            0.0
# actors              0.0
# year                0.0
# runtime_minutes     0.0
# rating              0.0
# votes               0.0
# revenue_millions    0.0
# metascore           0.0
# dtype: float64

# %% [markdown]
# **Observation:**
#
# Data is clear without null values. The rows are 1000 and columns are 12 , same count as obtained originally.

# %% [markdown]
# ### **Handling redundant data**

# %%
duplicate = df_Movie[df_Movie.duplicated()]
duplicate
# Out:
# Empty DataFrame
# Columns: [rank, title, genre, description, director, actors, year, runtime_minutes, rating, votes, revenue_millions, metascore]
# Index: []

# %% [markdown]
# **Observation:**
#
# Overall , no duplicate rows found, This we have observed in pre profiling report also

# %% [markdown]
# ###**Handling Inconsistent Data**

# %%
df_Movie.title.nunique()
# Out:
# 999

# %%
# check if there are multiple movies with the same title, and if so, determine if they are actually duplicates
dupe_titles = df_Movie[df_Movie.title.duplicated()].title
df_Movie[df_Movie.title.isin(dupe_titles)]
# Out:
#      rank     title  ... revenue_millions metascore
# 239   240  The Host  ...            26.62      35.0
# 632   633  The Host  ...             2.20      85.0
#
# [2 rows x 12 columns]

# %% [markdown]
# **Observation:**
#
# One Title found duplicated, Other than title all other columns are different. So we can ignore.
#
# So, no duplicate rows in the dataset.

# %% [markdown]
# ### **Creating Columns**

# %% [markdown]
# **Creating "avg_rating" Column based on metascore and rating**

# %% [markdown]
# Why it is required?
#
# The General Audience and the Critics
# As a part of this analysis, we will figure out the highest rated movies which have been liked by critics and audiences alike.
#
# Firstly you will notice that the metascore is on a scale of 100 whereas the rating is on a scale of 10. First, convert the metascore column to a scale of 10.
#
# Create a new column **"avg_rating"** which will have the average of the MetaCritic and Rating columns

# %%
df_Movie['metascore']=df_Movie['metascore']/10
df_Movie.insert(12,column='avg_rating',value=df_Movie.loc[:,['metascore','rating']].mean(axis=1))
df_Movie.sort_values(by='avg_rating',ascending=False,inplace=True)

# %% [markdown]
# **Creating "unique_genre" based on starting main genre in the combination**

# %%
df_Movie['unique_genre'] = df_Movie['genre'].str.split(',')
unique_genre = []

for gen in df_Movie['unique_genre']:
  for i in gen:
    if i not in unique_genre:
      unique_genre.append(i)

df_Movie['unique_genre'] = df_Movie['unique_genre'].apply(lambda x:x[0])

# %% [markdown]
# **View of dataset after creating columns**

# %%
df_Movie.shape
# Out:
# (1000, 14)

# %%
df_Movie.head(3)
# Out:
#      rank             title  ... avg_rating unique_genre
# 230   231   Pan's Labyrinth  ...       9.00        Drama
# 656   657           Boyhood  ...       8.95        Drama
# 111   112  12 Years a Slave  ...       8.85    Biography
#
# [3 rows x 14 columns]

# %%
#Creating Excel file after cleaning and adding columns
df_Movie.to_excel('Cleaned_Movies_Data.xlsx')

# %% [markdown]
# ####**Cleaning process is completed without loosing data. Data is now clear to proceed on Analysis part**

# %% [markdown]
# ---
# <a name = Section7></a>
# # **7. Data Post-Profiling**
# ---
#
# - The data is now clean, Let us create and check post profiling report and list some obervations.
# - The output file name which will store to content is "Post-Profiling_Report_MovieData.html"

# %%
#Output profile report from dataframe
 
#profile=ProfileReport(df_Movie)
 
#profile.to_file("Post-Profiling_Report_MovieData.html")

# %% [markdown]
# **Observation:**
#
#  - Post Profiling report is very clear without missing values etc.
#
#  - The columns are now 14 with same 1000 rows.
#
#  - The distributions also looks good, Some data are having outliers which are part of the data.
#
#  - Lest's start exploring the data.

# %% [markdown]
# ---
# <a name = Section8></a>
# # **8. Exploratory Data Analysis**
# ---
#
# - This section is emphasised on asking the right questions and perform analysis using the data.
#
#
# <img src='https://drive.google.com/uc?id=1NYc_7IUEa5w_dVttRmmPwmjZYsrCQZeI' width="600" ></img>
#
# - Exploratory Data Analysis refers to the critical process of performing investigations on data so as
#  - to discover patterns
#  - to spot anomalies
#  - to test hypothesis
#  - to check assumptions with the help of summary statistics and graphical representations.

# %% [markdown]
# ####<font color='blue'>**Top 10 High Revenue Movies**</font>

# %%
#Top 10 high revenue movies
df_Movie.loc[:,['title','revenue_millions','director','rating','votes','metascore','year']].sort_values(by = 'revenue_millions', ascending = False)[:10]
# Out:
#                                           title  ...  year
# 50   Star Wars: Episode VII - The Force Awakens  ...  2015
# 87                                       Avatar  ...  2009
# 85                               Jurassic World  ...  2015
# 76                                 The Avengers  ...  2012
# 54                              The Dark Knight  ...  2008
# 12                                    Rogue One  ...  2016
# 119                                Finding Dory  ...  2016
# 94                      Avengers: Age of Ultron  ...  2015
# 124                       The Dark Knight Rises  ...  2012
# 578             The Hunger Games: Catching Fire  ...  2013
#
# [10 rows x 7 columns]

# %% [markdown]
# **Observation:**
#
# Always interested to look into high revenue movies. The above are the list.

# %% [markdown]
# ####<font color='blue'>**Top 10 Movies of Critics and Audience Rating(Inferred Column)**</font> **(Based on our New column created with metascore and rating)**

# %%
df_Movie.loc[:,['title','revenue_millions','avg_rating','director','year']].sort_values(by = 'avg_rating', ascending = False)[:10]
# Out:
#                      title  revenue_millions  ...            director  year
# 230        Pan's Labyrinth             37.62  ...  Guillermo del Toro  2006
# 656                Boyhood             25.36  ...   Richard Linklater  2014
# 111       12 Years a Slave             56.67  ...       Steve McQueen  2013
# 6               La La Land            151.06  ...     Damien Chazelle  2016
# 241             Inside Out            356.45  ...         Pete Docter  2015
# 489            Ratatouille            206.44  ...           Brad Bird  2007
# 21   Manchester by the Sea             47.70  ...    Kenneth Lonergan  2016
# 688            Toy Story 3            414.98  ...         Lee Unkrich  2010
# 192              Spotlight             44.99  ...        Tom McCarthy  2015
# 41               Moonlight             27.85  ...       Barry Jenkins  2016
#
# [10 rows x 5 columns]

# %% [markdown]
# **Observation:**
#
# This shows even with good rating, some movies can't able to get good revenue.

# %% [markdown]
# ####<font color='blue'>**Top 10 High Rated Movies (Customer Rating)**</font>

# %%
#Top 10 High-rated movies
df_Movie.loc[:,['title','revenue_millions','rating','director','year']].sort_values(by = 'rating', ascending = False)[:10]
# Out:
#                      title  ...  year
# 54         The Dark Knight  ...  2008
# 80               Inception  ...  2010
# 117                 Dangal  ...  2016
# 249       The Intouchables  ...  2011
# 96           Kimi no na wa  ...  2016
# 36            Interstellar  ...  2014
# 991       Taare Zameen Par  ...  2007
# 124  The Dark Knight Rises  ...  2012
# 64            The Prestige  ...  2006
# 476    The Lives of Others  ...  2006
#
# [10 rows x 5 columns]

# %% [markdown]
# **Observation:**
#
#  - Movie "Star Wars: Episode VII - The Force Awakens" good in generating more revenue followed by avengers
#  - Movie "Pan's labyrinth" highly rated Based on audience and critics rating.
#  - Movie "The Dark Knight" highly rated Based on audience.

# %% [markdown]
# **By observing above the question comes into mind**
#
# There is a difference in getting good rating with less no of votes v/s with more no of votes. Same as we look when we are buying in Amazon for stars with more no ratings.
#
# **we will find out quality movies which is having highest rating along with more votes.**

# %% [markdown]
# ####<font color='blue'>**Top 10 High Rated Movies With More No of Votes**</font>

# %%
# Filter out all Quality movies into a new DataFrame

C = df_Movie['rating'].mean()
m = df_Movie['votes'].quantile(0.90)

Quality_Movies = df_Movie.copy().loc[df_Movie['votes'] >= m]
Quality_Movies.shape
# Out:
# (100, 14)

# %%
# Function that computes the weighted rating of each movie
def weighted_rating(x, m=m, C=C):
    v = x['votes']
    R = x['rating']
    # Calculation based on the formula
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
#Creating column score based on our function
Quality_Movies['score'] = Quality_Movies.apply(weighted_rating, axis=1)

# %%
#Sort movies based on score calculated above
Quality_Movies = Quality_Movies.sort_values('score', ascending=False)

# %%
#Top 10 movies highest rated with  more no of votes
Quality_Movies[['title', 'votes', 'rating', 'score','genre','revenue_millions']].head(10)
# Out:
#                      title  ...  revenue_millions
# 54         The Dark Knight  ...            533.32
# 80               Inception  ...            292.57
# 36            Interstellar  ...            187.99
# 124  The Dark Knight Rises  ...            448.13
# 99            The Departed  ...            132.37
# 64            The Prestige  ...             53.08
# 144       Django Unchained  ...            162.80
# 77    Inglourious Basterds  ...            120.52
# 634                 WALL·E  ...            223.81
# 249       The Intouchables  ...             13.18
#
# [10 rows x 6 columns]

# %% [markdown]
# **Observation:**
#
# "The Dark Knight" stood steadily at top followed by inception with more ratings and votes
#
# The Movies: 'Inception', 'Interstellar','The Departed' and 'The Prestige' generated low Revenue even with Higher Ratings, and Votes.
# 'Wall E', 'Django Unchained' Movies have performed well in proportional to Ratings and votes.

# %% [markdown]
# ####<font color='blue'>**Rating Below (6.5 is taken) and Check Revenue is Higher**</font>

# %%
#Highest revenue grosser even rating is less than 6.5
df_Movie[((df_Movie['year'] >= 2006) & (df_Movie['year'] <= 2016))
      & (df_Movie['rating'] < 6.5)
      & (df_Movie['revenue_millions'] > df_Movie['revenue_millions'].quantile(0.95))][:5]
# Out:
#      rank  ... unique_genre
# 767   768  ...       Action
# 344   345  ...       Action
# 400   401  ...    Animation
# 941   942  ...    Adventure
# 366   367  ...    Adventure
#
# [5 rows x 14 columns]

# %% [markdown]
# **Observation:**
#
# Rating is below 6.5 but revenue is good for the above movies

# %% [markdown]
# ####<font color='blue'>**Highest and Lowest Revenue Movies Data**</font>

# %%
#Function to display Min and max Movie details
def min_max(col_name):
  '''
  Function to display Min and max Movie details
  ''' 
  min_index=df_Movie[col_name].idxmin()
  max_index=df_Movie[col_name].idxmax()

  low=pd.DataFrame(df_Movie.loc[min_index,:])
  high=pd.DataFrame(df_Movie.loc[max_index,:])

  print('Movie which has highest '+col_name+' : ',df_Movie['title'][max_index])

  print('Movie which has lowest '+col_name+' : ',df_Movie['title'][min_index])

  return pd.concat([high,low],axis=1)

# %%
#Highest and Lowest revenue Movies
min_max('revenue_millions')
# Out:
# Movie which has highest revenue_millions :  Star Wars: Episode VII - The Force Awakens
# Movie which has lowest revenue_millions :  Lovesong
#                                                                 50                                                 321
# rank                                                             51                                                322
# title                    Star Wars: Episode VII - The Force Awakens                                           Lovesong
# genre                                      Action,Adventure,Fantasy                                              Drama
# description       Three decades after the defeat of the Galactic...  The relationship between two friends deepens d...
# director                                                J.J. Abrams                                        So Yong Kim
# actors            Daisy Ridley, John Boyega, Oscar Isaac, Domhna...  Riley Keough, Jena Malone, Jessie Ok Gray, Car...
# ...

# %% [markdown]
# **Observation:**
#
# Total details about Highest and Lowest revenue movies

# %% [markdown]
# ####<font color='blue'>**Top Directors with Average Rating is Higher**</font>

# %%
#Top Directors with average rating is higher 
df_Movie.groupby('director')[['rating']].mean().sort_values(['rating'], ascending=False).reset_index().head()
# Out:
#                            director  rating
# 0                     Nitesh Tiwari    8.80
# 1                 Christopher Nolan    8.68
# 2                    Makoto Shinkai    8.60
# 3                   Olivier Nakache    8.60
# 4  Florian Henckel von Donnersmarck    8.50

# %% [markdown]
# **Observation:**
#
# List of Directors with average rating is higher, for their right kind of movies.

# %% [markdown]
# ####<font color='blue'>**Plotting the distribution of Ratings,Revenue,Runtime and Votes**</font>

# %%
#Plotting the ditribution of Ratings,Revenue,Runtime and Votes
n_bins = 10 
fig, ((ax0, ax1), (ax2, ax3)) = plt.subplots(nrows=2, ncols=2,figsize=(20,15))
# set the spacing between subplots
#plt.subplots_adjust(left=0.1,bottom=0.1,right=0.9,top=0.9,wspace=0.4,hspace=0.4)
 
sns.histplot(df_Movie['rating'], ax=ax0,color='red',kde=True)
ax0.set(xlabel="Ratings")
 
sns.histplot(df_Movie['revenue_millions'], ax=ax1,color='green',kde=True)
ax1.set(xlabel="Revenue in Millions")

sns.histplot(df_Movie['runtime_minutes'], ax=ax2,color='blue',kde=True)
ax2.set(xlabel="Runtime in Minutes")
  
sns.histplot(df_Movie['votes'].tolist(), ax=ax3,color='magenta',kde=True)
ax3.get_xaxis().get_major_formatter().set_scientific(False)
ax3.set(xlabel="Votes")
sns.set_style("whitegrid")
#sns.set(rc={'figure.figsize':(11.7, 8.27)})
warnings.filterwarnings( "ignore", module = "matplotlib\..*" )

# %% [markdown]
# **Observation:**
#
# Revenue concentrated more below 150 million, some of them are above and Other are given oustanding revenue.
#
# Most frequent ratings are between 6 to 8.
#
# More no of votes concentrated at starting same as revenue distributed.
#
# Most movies have a runtime between 100 to 140.

# %% [markdown]
# ##<font color='black'>**Let's Plot Some Visualizations**</font>

# %% [markdown]
# ####<font color='blue'>**Year v/s Number of Movies Released**</font>

# %%
#group data according to their release year and count the total number of movies in each year and pot.
df_Movie.groupby('year').count()['rank'].plot(xticks = np.arange(2006,2016,1),figsize=(12,8))

#set the figure size and labels
#sns.set(rc={'figure.figsize':(10,6)})
plt.title("Year v/s Number of Movies", size = 20,color='blue')
plt.xlabel('Release Year', size = 16,color='brown')
plt.ylabel('Number of Movies', size = 16,color='brown')

sns.set_style("whitegrid")

# %% [markdown]
# **Observation:**
#
# The above plot shows that the number of movies per year was gradually increasing.
#
# But in 2016, count has grown all of a sudden signifying movie industry has become very popular.

# %% [markdown]
# ####<font color='blue'>**Movies Year v/s Revenue Sum**</font>

# %%
y_df = df_Movie[['year','revenue_millions']].copy()
y_sum=y_df.groupby('year').sum().reset_index()
#y_sum["year"] = pd.to_numeric(y_sum["year"])
y_sum.sort_values("revenue_millions", ascending=False).head(5)
# Out:
#     year  revenue_millions
# 10  2016          15677.51
# 9   2015           9526.40
# 8   2014           8189.48
# 7   2013           7810.78
# 6   2012           6910.29

# %%
#make group of the data according to their release year and Sum the totalRevenue in each year and pot.
df_Movie.groupby('year').sum()['revenue_millions'].plot(xticks = np.arange(2006,2016,1),figsize=(12,8))

#set the figure size and labels
#sns.set(rc={'figure.figsize':(12,7)})
plt.title("Year Vs Revenue Sum", size = 20,color='blue')
plt.xlabel('Release year', size = 16,color='brown')
plt.ylabel('Sum of Revenue', size = 16,color='brown')
#set the style sheet
sns.set_style("whitegrid")

# %% [markdown]
# **Observation:**
#
# Total Revenue was gradually increasing with Years.
#
# Key point is that, There is sudden increase in the Revenue in 2012,2013 and again in 2016.
#
# Slightly stable in 2014.
#
# The year 2016 generated highest total revenue.

# %% [markdown]
# ####<font color='blue'>**Movies Year v/s Revenue Full Distribution**</font>

# %%
figure=plt.figure(figsize=[12,8])

#sns.set_theme(style="whitegrid")
#tt = sns.load_dataset("df_Movie")
ax = sns.violinplot(x="year", y="revenue_millions", data=df_Movie)

plt.xlabel('Released Year', size = 16,color='brown')
plt.ylabel('Revenue in Millions', size = 16,color='brown')
plt.title('Movie Revenue by Year ', size = 20, color = 'Blue')
warnings.filterwarnings( "ignore", module = "matplotlib\..*" )

# %% [markdown]
# **Observation:**
#
# Highest earning movie was released in 2015(due to Start Wars VII) followed by 2009(Avatar) and then 2012(The Avengers).

# %% [markdown]
# ####<font color='blue'>**Top Movies with Highest Revenue and their Genre**</font>

# %%
plt.figure(figsize=(12,8))
df4=df_Movie.sort_values("revenue_millions", ascending=False).head(10)
df_4 = sns.barplot(x="revenue_millions", y="title",hue='genre', linewidth=0, data=df4,ci= None,palette="Set2")
plt.ylabel('Title', size = 16,color='brown')
plt.xlabel('Revenue in Millions', size = 16,color='brown')
plt.title('Top Movies with Highest Revenue and their Genre', size = 20, color = 'Blue')
df_4.set_xlim(300,1000)
plt.legend(bbox_to_anchor=(1.05, 0.9), loc=2, borderaxespad=0.)  #Moving the hue to right for graph visibility.
plt.show()

# %% [markdown]
# **Observation:**
#
# From the barplot, the movie with highest revenue is: 'Star Wars Episode VII' directed by J.J.Abrams.Its revenue is nearly 930 millions.
#
# 'Avatar' and 'Jurassic World' are the next highest reveneue generators of about 760 millions and 650 millions respectively.

# %% [markdown]
# ####<font color='blue'>**Actors With More No of Movies**</font>

# %%
#make a function which will split the string and return the count.
def count_coldata(x):
  '''
  function which will split the string and return the count.
  '''
  #concatenate all the rows of the genrs.
  Vdata_plot = df_Movie[x].str.cat(sep = ',')
  dataV = pd.Series(Vdata_plot.split(','))
  #counts each of the genre and return.
  info = dataV.value_counts(ascending=False)
  return info

# %%
#Top 15 Actors done most of movies
#call the 'count_coldata' function which we made earlier for spiliing and counting.
#it wiil count number of movies done by each actor.
count_actor = count_coldata('actors')

#plot the barh plot.
count_actor.iloc[:15].plot.bar(figsize=(13,6),fontsize=12,color=['m'])

#setup the title and the labels of the plot.
plt.title("Actors With More No of Movies", size = 20,color='blue')
#plt.xticks(rotation = 70)
plt.xlabel('Actor', size = 16,color='brown')
plt.ylabel("Number Of Movies", size = 16,color='brown')
sns.set_style("whitegrid")

# %% [markdown]
# **Observation:**
#
# 'Mark Wahlberg' and 'Christian Bale' worked in 15 Movies and stood at top.
#
# The next 9 actors are part of 9 movies each.

# %% [markdown]
# ####<font color='blue'>**Directors With More No of Movies**</font>

# %%
#call the 'count_coldata' function which we made earlier for splitting and counting.
#it wiil count number of movies by each director.
directorDS = count_coldata('director')


#plot he barh plot.

directorDS.iloc[:15].plot(kind='barh',figsize=(16,8),fontsize=13,color=['#029386'])
plt.title("Director v/s Number of Movies", size = 20,color='blue')
plt.xlabel('Number of Movies', size = 16,color='brown')
plt.ylabel('Director', size = 16,color='brown')
sns.set_style("whitegrid")

# %% [markdown]
# **Observation:**
#
# More no of directors contributed repeated times for the movies.

# %% [markdown]
# ####<font color='blue'>**Top 10 Successful Directors**</font>

# %%
#Top 10 Successful Directors
director_list = df_Movie.groupby('director')['revenue_millions'].count().sort_values(ascending=False)
director_list = list(director_list[director_list >= 5].index)
success_df = df_Movie[(df_Movie['revenue_millions'] > 1) & (df_Movie['director'].isin(director_list))]
sdf=pd.DataFrame(success_df.groupby('director')['revenue_millions'].mean().sort_values(ascending=False).reset_index().head(10))
sdf.set_index('director').reset_index()

sdf.plot(kind='barh',x='director',y='revenue_millions')

warnings.filterwarnings( "ignore", module = "matplotlib\..*" )

# %% [markdown]
# **Observation:**
#
# Even though ‘Ridley Scott’ directed highest number of movies, when it comes to average revenue generation he is not performing well.
#
# ’J.J. Abrams' generated highest total revenue of 336m with only 5 movies.
# ‘Christopher Nolan’ also generated average revenue of 303m with 5 movies and stood at position 2. This makes them the most successful directors than any other till 2016.

# %% [markdown]
# ####<font color='blue'>**Distribution of Revenue and Votes in combination with Ratings,Year and Title on Hover**</font>

# %%
fig=px.scatter(df_Movie,x='revenue_millions',y='votes',size='votes',color = 'rating',hover_name='title',animation_frame='year',
           title="Distribution of Revenue and Votes")
config = dict({'scrollZoom': True})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9357b9de-aaa7-458f-84e5-985b286b24ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9357b9de-aaa7-458f-84e5-985b286b24ad")) {
#                     Plotly.newPlot(
#                         '9357b9de-aaa7-458f-84e5-985b286b24ad',
# ...

# %% [markdown]
# **Observation:**
#
# From the above plot we observe that their are movies which has Higher Rating along with Higher Votes still Revenue is not up to the Mark. Year - 2012 (Django Unchained) Year - 2014 (Interstellar) Year - 2006 (The Prestige,The Departed)
#
# The Graph can be scrolled horizontal and vertical to view more

# %% [markdown]
# ####<font color='blue'>**Votes and Runtime v/s Revenue along with Rating**</font>

# %%
n_bins = 10  
fig, (ax0, ax2) = plt.subplots( ncols=2,figsize=(18,12))
# set the spacing between subplots
#plt.subplots_adjust(left=0.1,bottom=0.1,right=0.9,top=0.9,wspace=0.4,hspace=0.4)

#hb = ax0.hexbin(df_Movie['votes'], df_Movie['revenue_millions'],gridsize=20, edgecolors='grey',cmap='inferno', mincnt=1)
#hb1 = ax2.hexbin(df_Movie['runtime_minutes'], df_Movie['revenue_millions'],gridsize=20, edgecolors='grey',cmap='inferno', mincnt=1)
#cb = fig.colorbar(hb, ax=ax0)
#cb1 = fig.colorbar(hb1, ax=ax2)
 
sns.scatterplot(data=df_Movie ,x='votes', y='revenue_millions',hue='rating', ax=ax0, palette='Oranges')
ax0.set(xlabel="Votes")
ax0.set(title="Votes  V/S  Movie Revenue")

sns.scatterplot(data=df_Movie ,x='runtime_minutes', y='revenue_millions',hue='rating', ax=ax2, palette='Greens')
ax2.set(xlabel="Runtime in Minutes")
ax2.set(title="Runtime  V/S  Movie Revenue")

ax0.get_xaxis().get_major_formatter().set_scientific(False)

#sns.set(rc={'figure.figsize':(18,9)})

plt.show()
warnings.filterwarnings( "ignore", module = "matplotlib\..*" )

# %% [markdown]
# **Observation:**
#
# 1. The scatter plot of vote v/s revenue will help us understand if movies with more votes generate higher revenue or not.
#
# 2. The scatter plot of Runtime v/s revenue will help us understand if movies with more Runtime generate higher revenue or not.
#
# We observe that movies close to a runtime from 100 to 140 minutes are possible to register higher returns.
#
# We can see that, although the correlation coefficient is positive between votes and revenue, the relationship is not much stronger.

# %% [markdown]
# ####<font color='blue'>**Most Filmed Genre (Counted anywhere in genre column)**</font>

# %%
#call the function for counting the movies of each genre.
total_genre_movies = count_coldata('genre')
#plot a 'barh' plot using plot function for 'genre vs number of movies'.
total_genre_movies.plot(kind= 'barh',figsize = (13,6),fontsize=12,color=['black', 'red', 'green', 'blue'])

#setup the title and the labels of the plot.
plt.title("Most Filmed Genre(Counted anywhere in genre column)",fontsize=20,color='Blue')
plt.xlabel('Number Of Movies',fontsize=16,color='brown')
plt.ylabel("Genres",fontsize= 16,color='brown')
#sns.set_style("whitegrid")
#sns.set_theme(style='dark',palette='Oranges')
warnings.filterwarnings( "ignore", module = "matplotlib\..*" )

# %% [markdown]
# **Observation:**
#
# From above chart,
# Movies with drama genre are highest followed by Action and Comedy Genre.
# At the same time, they are the most repetitive genres.
#
# Genres with lowest movies are Musical, western, war Genre

# %% [markdown]
# ####<font color='blue'>**Revenue of Most Filmed Genre (Original genre - having Combination)**</font>

# %%
grouped_gen_rev = df_Movie.groupby('genre')['revenue_millions'].sum().reset_index()
grouped_gen_rev=grouped_gen_rev.sort_values('revenue_millions',ascending=False)
#grouped_gen_rev

# %%
#grouped_gen_rev = df_Movie.groupby('genre')['revenue_millions'].sum().reset_index()
fig = px.pie(grouped_gen_rev[:10], names='genre', values='revenue_millions')
fig.update_traces(textposition='inside', textinfo='percent+label+value',pull=[0.1, 0, 0, 0])
fig.update_layout(title='Revenue and Contribution of Combined Genre')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a4e993fc-e259-4f34-8297-6aa08aa44fe2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a4e993fc-e259-4f34-8297-6aa08aa44fe2")) {
#                     Plotly.newPlot(
#                         'a4e993fc-e259-4f34-8297-6aa08aa44fe2',
# ...

# %% [markdown]
# **Observation:**
#
# Action,Adventure,sci-fi combination contibuted 30% of revenue in top 10 contributors

# %% [markdown]
# ####<font color='blue'>**Revenue of Most Filmed Genre (Main Genre is Considered)**</font>

# %%
main_gen_rev = df_Movie.groupby('unique_genre')['revenue_millions'].sum().reset_index()
main_gen_rev=main_gen_rev.sort_values('revenue_millions',ascending=False)
#main_gen_rev

# %%
main_gen_rev = df_Movie.groupby('unique_genre')['revenue_millions'].sum().reset_index()

fig = px.pie(main_gen_rev[:10], names='unique_genre', values='revenue_millions')
fig.update_traces(textposition='inside', textinfo='percent+label+value',pull=[0.1, 0, 0.1, 0.2])
fig.update_layout(title='Revenue and Contribution of Main Title Genre')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="50004915-0efe-4ce8-a1ca-8eaaffa8a095" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("50004915-0efe-4ce8-a1ca-8eaaffa8a095")) {
#                     Plotly.newPlot(
#                         '50004915-0efe-4ce8-a1ca-8eaaffa8a095',
# ...

# %% [markdown]
# **Observation:**
#
# From the above graph, understood that Action genre has earned most revenue followed by Animation,Comedy.
#
# Horror,Mystery,Fantasy has not made much revneue

# %% [markdown]
# ####<font color='blue'>**Genre Heat Map(Average Revenue per Genre per Year)**</font>

# %%
GenDF = df_Movie[['rank','title','runtime_minutes', 'genre','votes','rating','revenue_millions','year']]
GenDF.set_index('rank', inplace=True)

# Split genres and create a new entry for each of the genre a movie falls into
s = GenDF['genre'].str.split(',').apply(Series, 1).stack()
s.index = s.index.droplevel(-1)
s.name = 'genre'
del GenDF['genre']
GenDF_split_genres = GenDF.join(s)
#GenDF_split_genres.shape

# %%
# Create data frame for average profit per genre per year
md_year_genre_profit = pd.DataFrame(GenDF_split_genres.groupby(['year','genre'])['revenue_millions'].mean())
#md_year_genre_profit.head()

# %%
# pivot data to get the shape that is necessary for a heatmap that displays genres, years and avg. profit per genre per year
md_heat_profit_pivot = pd.pivot_table(md_year_genre_profit, values='revenue_millions', index=['genre'], columns=['year'])
#md_heat_profit_pivot.head()

# %%
# display heatmap
#Revenue per Genre per year
sns.set(rc={'figure.figsize':(15,10)})
#YlGnBu
sns.heatmap(md_heat_profit_pivot, linewidths=.5, cmap='copper_r');

# %% [markdown]
# **Observation:**
#
# Average revenue of animation is more in 2013 and 2015 and in other years also

# %% [markdown]
# ####<font color='blue'>**Properties associated with Revenue of Movies**</font>

# %%
 
n_bins = 10 
fig, ((ax0, ax1), (ax2, ax3)) = plt.subplots(nrows=2, ncols=2,figsize=(15,10))
# set the spacing between subplots
#plt.subplots_adjust(left=0.1,bottom=0.1,right=0.9,top=0.9,wspace=0.4,hspace=0.4)
 
sns.regplot(x=df_Movie['revenue_millions'],y=df_Movie['rating'], ax=ax0,color='r')
#ax0.set(xlabel="Ratings")
 
sns.regplot(x=df_Movie['revenue_millions'],y=df_Movie['votes'], ax=ax1,color='g')
#ax1.set(xlabel="Votes")

sns.regplot(x=df_Movie['revenue_millions'],y=df_Movie['metascore'], ax=ax2,color='b')
#ax2.set(xlabel="Critics Rating")
  
sns.regplot(x=df_Movie['revenue_millions'],y=df_Movie['runtime_minutes'], ax=ax3,color='m')
ax3.get_xaxis().get_major_formatter().set_scientific(False)
#ax3.set(xlabel="Runtime")

#sns.set(rc={'figure.figsize':(11.7, 8.27)})
warnings.filterwarnings( "ignore", module = "matplotlib\..*" )

# %%
def plot_correlation_map( df ):
    corr = df.corr()
    _ , ax = plt.subplots( figsize =( 12 , 10 ) )
    cmap = sns.diverging_palette( 240 , 10 , as_cmap = True )
    _ = sns.heatmap(corr,cmap = cmap,square=True, cbar_kws={ 'shrink' : .9 }, ax=ax, annot = True, annot_kws = { 'fontsize' : 12 })

# %%
##Correlation matrix
#df_Movie.corr <- na.omit(movies)

plot_correlation_map(df_Movie[['revenue_millions','runtime_minutes','votes','rating','metascore']])

# %% [markdown]
# **Observation:**
#
# **Rating vs Revenue**
#
# The correlation between revenue and rating is 0.22. So vote average is not highly related to the revenue
#
# **Runtime vs Revenue**
#
# The correlation between revenue and runtime is 0.27. So runtime is not highly related to the revenue.
#
# **Votes vs Revenue**
#
# The revenue seems to be increasing with votes. We can say that if the votes of movie is high then the revenue of the movie may be high.Correlation is 0.64
#
# **Metascore vs Revenue**
#
# Metascore correlation with Revenue is very weak.

# %% [markdown]
# ---
# <a name = Section9></a>
# # **9. Summarization**
# ---
#
#
# <img src='https://drive.google.com/uc?id=1lygXms66d2Ax9YjsLf66rMV2gc49uNg3' width="500" ></img>

# %% [markdown]
# <a name = Section91></a>
# ### **9.1 Conclusion**
#
# Following are some of the questions we are trying to answer with our exploratory data analysis.
#
# How genres contribute to the Revenue by comparing the revenue between different genres.
#
# How industry performed in terms of number of movies over the years
#
# How is the distribution of movies with repect to ratings, vote counts and several other factors present in the dataset. We are planning to use scatter plots at the basic level to get some feel of the data.
#
# Are there unicorn directors and actors that have better track record in terms of producing more successful movies.

# %% [markdown]
# <a name = Section92></a>
# ### **9.2 Actionable Insights**

# %% [markdown]
# **Movie Inferences**
#
#  - The movie revenue is increasing over years and revenue shoot up in 2012,2013 and 2016, Which proves it as most profitable industry when years advance.
#
#  - Top Revenue Movies are Star Wars: Episode VII(930m),Avatar(760m),Jurassic world(650m) etc.
#
#  - Highest earning movie was released in 2015(due to Start Wars VII) followed by 2009(Avatar) and then 2012(The Avengers).
#
#  - "The Dark Knight" released in 2008 stood top at rating and votes and proved well in all categories.
#
# **Genre Inferences**
#
#  - Action, Adventure and Animation movies tend to be most profitable as per Genre Analaysis.
#
#  - There were very few mystery, western or war genre movies
#
#  - Movies with combination of 2/3 Gener's are preferred by viewers compared to sole genre.
#
#  - The Drama Movies are filmed more according to count of genre, followed by Action, comedy .
#
#  - Animation movies given more average revenue in 2013 and 2015 and in other years.
#
# **Directors**
#
#  - ’J.J. Abrams' generated highest total revenue of 336m with only 5 movies.
# ‘Christopher Nolan’ also generated average revenue of 303m with 5 movies and stood at position 2. This makes them the most successful directors than any other till 2016.
#
#  - Director with average rating is higher are
#   - Nitesh Tiwari - 8.80 ,  Christopher Nolan - 8.68 and follows.
#
#
#  **Actors**
#
#  - 'Mark Wahlberg' and 'Christian Bale' worked in 15 Movies and stood at top.
#
# **Runtime**
#
#  - Runtime does not affect movie revenue that much. but one inference can be drawn from scatter plot, runtime between 100 to 140 are filmed more and ratings is also good.
#
# **Ratings**
#
# - The movies with ratings below 6.5 but revenue is good, which are
#   - Indiana Jones and the Kingdom of the Crystal Skull directed by Steven Spielberg
#   - Spider-Man 3 directed by Sam Raimi
#   - Minions directed by Kyle Balda
#
# - The Quality movies rated with more no of votes are most preferrable movies, which are Dark Knight,Inception,Interstellar etc.
#
# - Audience ratings of the movies are quite close to those of the critics ratings Movies that are well rated by public make the most money.
#
# **Thank you for taking the time to read through this Movie Data Analysis**
